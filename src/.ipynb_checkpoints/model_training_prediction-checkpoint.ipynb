# %%
import os 
import pickle
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
Input, Conv2D, MaxPooling2D, UpSampling2D, Conv2DTranspose,
Concatenate, BatchNormalization, Dropout, Lambda)

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import Loss

from tensorflow.keras import backend as K
from tensorflow.keras.saving import register_keras_serializable

# %%
import tensorflow as tf
print(f"Tensorflow version: {tf.__version__}")
# Out:
# Tensorflow version: 2.19.0

# %% [markdown]
# #### Load train-test data

# %%
from tensorflow import keras
print(f"Keras version: {keras.__version__}")
# Out:
# Keras version: 3.9.1

# %%
INPUT_DATA_FILE = '../data/training_data.pkl'

# %%
with open(INPUT_DATA_FILE, 'rb') as f:
    data = pickle.load(f)

X_train = data['X_train']
X_test = data['X_test']
y_train = data['y_train']
y_test = data['y_test']
label_map = data['label_map']
class_labels_rgb = data['class_labels_rgb']

# %%
NUM_IMGS, IMG_H, IMG_W, IMG_C = X_train.shape
NUM_CLASSES = len(label_map.keys())
print(f"Total number of images: {NUM_IMGS}")
print(f"Image height: {IMG_H}")
print(f"Image width: {IMG_W}")
print(f"Image channels: {IMG_C}")
print(f"Total Classes: {NUM_CLASSES}")
# Out:
# Total number of images: 247
# Image height: 256
# Image width: 256
# Image channels: 3
# Total Classes: 6

# %% [markdown]
# #### U-NET Model
#
# U-Net is a neural network model dedicated to computer vision tasks and more particularly to semantic segmentation problems.
#
# **Semantic Segmentation**
#
# Semantic segmentation involves labelling each pixel in an image with a class corresponding to what is being represented. This is also known as "dense prediction" as each pixel must be predicted.
#
# Unlike other computer vision tasks, semantic segmentation does not just produce labels and bounding boxes. It generates a high-resolution image, in which each pixel is classified.
#
# **Applications of Semantic Segmentation**
#
# - Autonomous vehicles require perception, planning and execution in constantly changing environments.
# - Medical diagnostics
# - Satellite Mapping can use semantic segmentation to detect buildings and roads for traffic management and urban planning.
# - Precision Agriculture Robots can use semantic segmentation to distinguish plantation from weeds.
#
# **Instance Segmentation** is a more advanced version. If an image shows three dogs, each dog is an instance of the class "Dog". Each will be classified separately, for example, using different colors.
#
# The U-Net architecture is one of the most widely use neural networks for image segmentation. It is composed of two paths. The first is the contraction path, also known as the __encoder__. It is used to capture the context of an image. It is an assembly of convolution and max pooling layers for reducing the number of network parameters. The second path is the symmetric expansion path, also known as the __decoder__. It allows for accurate localization through transposed convolution.

# %%
def conv_block(m_input, num_filters, kernel_size, activation, kernel_initializer, padding, dropout):
    x = Conv2D(
        num_filters, kernel_size, activation=activation, 
        kernel_initializer=kernel_initializer, padding=padding
    )(m_input)
    x = Dropout(dropout)(x)
    c1 = Conv2D(
        num_filters, kernel_size, activation=activation, 
        kernel_initializer=kernel_initializer, padding=padding
    )(x)
    # x = Dropout(dropout)(x)
    return x

def encoder_block(m_input, num_filters, kernel_size, activation, kernel_initializer, padding, dropout):
    x = conv_block(m_input, 32, (3, 3), activation, kernel_initializer, padding, dropout)
    p = MaxPooling2D((2,2))(x)
    return x, p

def decoder_block(inputs, skip_features, num_filters, kernel_size_t, strides, kernel_size, activation, kernel_initializer, padding, dropout):
    x = Conv2DTranspose(num_filters, kernel_size_t, strides=strides, padding=padding)(inputs)
    x = Concatenate()([x, skip_features])
    x = conv_block(x, num_filters, kernel_size, activation, kernel_initializer, padding, dropout)
    return x

def unet_model(n_classes, image_height, image_width, image_channels, start_filters=16):

    activation = "relu"
    kernel_initializer = "he_normal"
    padding = "same"
    dropout = 0.1

    model_input = Input((image_height, image_width, image_channels))
    c1, p1 = encoder_block(model_input, start_filters, (3, 3), activation, kernel_initializer, padding, dropout)
    c2, p2 = encoder_block(p1, 2*start_filters, (3, 3), activation, kernel_initializer, padding, dropout)
    c3, p3 = encoder_block(p2, 4*start_filters, (3, 3), activation, kernel_initializer, padding, dropout)
    c4, p4 = encoder_block(p3, 6*start_filters, (3, 3), activation, kernel_initializer, padding, dropout)

    b1 = conv_block(p4, 8*start_filters, (3, 3), activation, kernel_initializer, padding, dropout)

    d1 = decoder_block(b1, c4, 6*start_filters, (2,2), (2,2), (3,3), activation, kernel_initializer, padding, dropout)
    d2 = decoder_block(d1, c3, 4*start_filters, (2,2), (2,2), (3,3), activation, kernel_initializer, padding, dropout)
    d3 = decoder_block(d2, c2, 2*start_filters, (2,2), (2,2), (3,3), activation, kernel_initializer, padding, dropout)
    d4 = decoder_block(d3, c1, start_filters, (2,2), (2,2), (3,3), activation, kernel_initializer, padding, dropout)
    
    outputs = Conv2D(n_classes, (1,1), activation="softmax", padding="same")(d4)

    return Model(model_input, outputs, name="U-Net")

# %% [markdown]
# **Evaluation Metrics**
#
# We'll use Jaccard Index / Intersection over Union (IoU) as the evaluation metrics. The Jaccard index is a statistics used for gauging the similarity and diversity of sample sets. It is defined in general by taking the ratio of the intersection size and the union size, also called IoU.
#
# \begin{equation}
# J(A,B) = \frac{|A \cap B|}{|A \cup B|}
# \end{equation}
#
# The Jaccard distance, on the other hand, is complementary to the Jaccard Index and is obtained by subtracting the Jaccard Index from 1. It measures the dissimilarity between sample sets.
#
# \begin{equation}
# d_J(A,B) = 1 - J(A,B)
# \end{equation}

# %%
K.flatten(y_train).shape
# Out:
# TensorShape([97124352])

# %%
@register_keras_serializable()
def multiclass_jaccard_index(y_true, y_pred, smooth=1e-6):
    assert y_true.shape == y_pred.shape
    y_true_flatten = K.flatten(y_true)
    y_pred_flatten = K.flatten(y_pred)
    intersection = K.sum(y_true_flatten * y_pred_flatten)
    jaccard_index = (intersection + smooth) / (K.sum(y_true_flatten) + K.sum(y_pred_flatten) - intersection + smooth)
    return jaccard_index

# %%
metrics = ["accuracy", multiclass_jaccard_index]

# %%
def get_model():
    return unet_model(NUM_CLASSES, IMG_H, IMG_W, IMG_C)

# %%
model = get_model()

# %%
model.summary()
# Out:
# Model: "U-Net"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_5       │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_88 (Conv2D)  │ (None, 256, 256,  │        896 │ input_layer_5[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_42          │ (None, 256, 256,  │          0 │ conv2d_88[0][0]   │
# │ (Dropout)           │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_20    │ (None, 128, 128,  │          0 │ dropout_42[0][0]  │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_90 (Conv2D)  │ (None, 128, 128,  │      9,248 │ max_pooling2d_20… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_43          │ (None, 128, 128,  │          0 │ conv2d_90[0][0]   │
# │ (Dropout)           │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_21    │ (None, 64, 64,    │          0 │ dropout_43[0][0]  │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_92 (Conv2D)  │ (None, 64, 64,    │      9,248 │ max_pooling2d_21… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_44          │ (None, 64, 64,    │          0 │ conv2d_92[0][0]   │
# │ (Dropout)           │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_22    │ (None, 32, 32,    │          0 │ dropout_44[0][0]  │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_94 (Conv2D)  │ (None, 32, 32,    │      9,248 │ max_pooling2d_22… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_45          │ (None, 32, 32,    │          0 │ conv2d_94[0][0]   │
# │ (Dropout)           │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_23    │ (None, 16, 16,    │          0 │ dropout_45[0][0]  │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_96 (Conv2D)  │ (None, 16, 16,    │     36,992 │ max_pooling2d_23… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_46          │ (None, 16, 16,    │          0 │ conv2d_96[0][0]   │
# │ (Dropout)           │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_17 │ (None, 32, 32,    │     49,248 │ dropout_46[0][0]  │
# │ (Conv2DTranspose)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_17      │ (None, 32, 32,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ dropout_45[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_98 (Conv2D)  │ (None, 32, 32,    │    110,688 │ concatenate_17[0… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_47          │ (None, 32, 32,    │          0 │ conv2d_98[0][0]   │
# │ (Dropout)           │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_18 │ (None, 64, 64,    │     24,640 │ dropout_47[0][0]  │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_18      │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 96)               │            │ dropout_44[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_100 (Conv2D) │ (None, 64, 64,    │     55,360 │ concatenate_18[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_48          │ (None, 64, 64,    │          0 │ conv2d_100[0][0]  │
# │ (Dropout)           │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_19 │ (None, 128, 128,  │      8,224 │ dropout_48[0][0]  │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_19      │ (None, 128, 128,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 64)               │            │ dropout_43[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_102 (Conv2D) │ (None, 128, 128,  │     18,464 │ concatenate_19[0… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_49          │ (None, 128, 128,  │          0 │ conv2d_102[0][0]  │
# │ (Dropout)           │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_20 │ (None, 256, 256,  │      2,064 │ dropout_49[0][0]  │
# │ (Conv2DTranspose)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_20      │ (None, 256, 256,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 48)               │            │ dropout_42[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_104 (Conv2D) │ (None, 256, 256,  │      6,928 │ concatenate_20[0… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_50          │ (None, 256, 256,  │          0 │ conv2d_104[0][0]  │
# │ (Dropout)           │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_106 (Conv2D) │ (None, 256, 256,  │        102 │ dropout_50[0][0]  │
# │                     │ 6)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 341,350 (1.30 MB)
#  Trainable params: 341,350 (1.30 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# model.get_config()

# %% [markdown]
# **Loss Function**
#
# For this exercise, we'll use a combination of dice loss and focal loss. A __Focal Loss__ function addresses class imbalance during training in tasks like object detection. Focal loss applies a modulating term to the cross entropy loss in order to focus learning on hard misclassified examples. It is a dynamically scaled cross entropy loss, where the scaling factor decays to zero as confidence in the correct class increases. Intuitively, this scaling factor can automatically down-weight the contribution of easy examples during training and rapidly focus the model on hard examples.
#
# Formally, the Focal Loss adds a factor $(1 - p_t)^\gamma$
#  to the standard cross entropy criterion. Setting $\gamma > 0$
#  reduces the relative loss for well-classified examples ($p_t > 0.5$
# ), putting more focus on hard, misclassified examples. Here there is tunable focusing parameter $\gamma \ge 0$
#
# \begin{equation}
# FL(p_t) = -(1 - p_t)^\gamma\log(p_t)
# \end{equation}

# %%
@register_keras_serializable()
class DiceFocalLoss(Loss):
    def __init__(self, alpha=0.25, gamma=2.0, dice_weight=0.5, focal_weight=0.5, 
                 smooth=1e-6, from_logits=False, name="dice_focal_loss", reduction = 'sum_over_batch_size'):
        super(DiceFocalLoss, self).__init__(name=name, reduction=reduction)
        self.alpha = alpha
        self.gamma = gamma
        self.dice_weight = dice_weight
        self.focal_weight = focal_weight
        self.smooth = smooth
        self.from_logits = from_logits
        
    def dice_loss(self, y_true, y_pred, use_true_union=False):
        """
        Calculate Dice Loss for multiclass segmentation.
        
        Args:
            y_true: Ground truth labels (batch_size, height, width, num_classes)
            y_pred: Predicted probabilities (batch_size, height, width, num_classes)
            use_true_union: If True, uses A+B-A∩B formula; if False, uses A+B (Sørensen-Dice)
        """
        # Calculate intersection by summing over spatial dimensions (axis 1,2) for each class
        intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2])  # Shape: (batch, num_classes)
        
        if use_true_union:
            # True set theory union: A + B - A∩B
            sum_sets = tf.reduce_sum(y_true, axis=[1, 2]) + tf.reduce_sum(y_pred, axis=[1, 2])
            union = sum_sets - intersection
        else:
            # Sørensen-Dice coefficient: A + B (more commonly used in segmentation)
            union = tf.reduce_sum(y_true, axis=[1, 2]) + tf.reduce_sum(y_pred, axis=[1, 2])
        
        # Dice coefficient for each class and batch
        dice_coeff = (2.0 * intersection + self.smooth) / (union + self.smooth)
        
        # Average across classes and batches
        dice_loss = 1.0 - tf.reduce_mean(dice_coeff)
        return dice_loss
    
    def focal_loss(self, y_true, y_pred):
        """
        Calculate Focal Loss for multiclass segmentation.
        
        Args:
            y_true: Ground truth labels (batch_size, height, width, num_classes)
            y_pred: Predicted probabilities (batch_size, height, width, num_classes)
        """
        # Clip predictions to prevent log(0)
        epsilon = tf.keras.backend.epsilon()
        y_pred = tf.clip_by_value(y_pred, epsilon, 1.0 - epsilon)
        
        # Standard cross entropy
        ce_loss = -y_true * tf.math.log(y_pred)
        
        # For focal loss, p_t is simply the predicted probability of the true class
        # Since y_pred is already probabilities and y_true is one-hot encoded:
        p_t = tf.reduce_sum(y_true * y_pred, axis=-1, keepdims=True)  # Extract prob of true class
        
        # Apply focal loss modulation: (1-p_t)^gamma
        focal_weight = tf.pow((1 - p_t), self.gamma)
        
        # Apply class weighting (alpha) and focal weight
        focal_loss = self.alpha * focal_weight * ce_loss
        
        # Return mean loss
        return tf.reduce_mean(focal_loss)
    
    def call(self, y_true, y_pred):
        """
        Calculate combined Dice + Focal Loss.
        """
        # Convert logits to probabilities if needed
        if self.from_logits:
            y_pred = tf.nn.softmax(y_pred, axis=-1)
        
        # Calculate individual losses
        dice_loss_val = self.dice_loss(y_true, y_pred)
        focal_loss_val = self.focal_loss(y_true, y_pred)
        
        # Combine losses with weights
        total_loss = (self.dice_weight * dice_loss_val + 
                     self.focal_weight * focal_loss_val)
        
        return total_loss

# %%
optimizer = Adam(learning_rate=0.0005)
model.compile(
    optimizer=optimizer,
    loss=DiceFocalLoss(),
    metrics=metrics
)

# %% [markdown]
# #### Model Training

# %%
NUM_EPOCHS = 100
model_history = model.fit(X_train, y_train, batch_size=16, epochs=NUM_EPOCHS, verbose=True, validation_data=(X_test, y_test), shuffle=True)
# Out:
# Epoch 1/100
# 2025-05-29 14:03:54.381135: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.34 = (f32[16,128,16,16]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,32,16,16]{3,2,1,0} %bitcast.29884, f32[128,32,3,3]{3,2,1,0} %bitcast.28130, f32[128]{0} %bitcast.29944), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="U-Net_1/conv2d_96_1/convolution" source_file="/home/jubranakram/virtual-envs/tf-ml/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-05-29 14:03:54.623065: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.35 = (f32[16,96,32,32]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,128,32,32]{3,2,1,0} %bitcast.30136, f32[96,128,3,3]{3,2,1,0} %bitcast.28172, f32[96]{0} %bitcast.30196), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="U-Net_1/conv2d_98_1/convolution" source_file="/home/jubranakram/virtual-envs/tf-ml/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-05-29 14:03:54.752226: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.36 = (f32[16,64,64,64]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,96,64,64]{3,2,1,0} %bitcast.30387, f32[64,96,3,3]{3,2,1,0} %bitcast.28214, f32[64]{0} %bitcast.30447), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="U-Net_1/conv2d_100_1/convolution" source_file="/home/jubranakram/virtual-envs/tf-ml/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-05-29 14:03:54.976568: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.37 = (f32[16,32,128,128]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,64,128,128]{3,2,1,0} %bitcast.30637, f32[32,64,3,3]{3,2,1,0} %bitcast.28256, f32[32]{0} %bitcast.30697), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="U-Net_1/conv2d_102_1/convolution" source_file="/home/jubranakram/virtual-envs/tf-ml/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-05-29 14:03:55.367168: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.38 = (f32[16,16,256,256]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,48,256,256]{3,2,1,0} %bitcast.30892, f32[16,48,3,3]{3,2,1,0} %bitcast.28298, f32[16]{0} %bitcast.30952), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="U-Net_1/conv2d_104_1/convolution" source_file="/home/jubranakram/virtual-envs/tf-ml/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 15/16 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.1322 - loss: 0.4999 - multiclass_jaccard_index: 0.0822
# 2025-05-29 14:04:04.841905: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.35 = (f32[7,96,32,32]{3,2,1,0}, u8[0]{0}) custom-call(f32[7,128,32,32]{3,2,1,0} %bitcast.30124, f32[96,128,3,3]{3,2,1,0} %bitcast.28172, f32[96]{0} %bitcast.30184), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="U-Net_1/conv2d_98_1/convolution" source_file="/home/jubranakram/virtual-envs/tf-ml/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-05-29 14:04:04.931043: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.36 = (f32[7,64,64,64]{3,2,1,0}, u8[0]{0}) custom-call(f32[7,96,64,64]{3,2,1,0} %bitcast.30371, f32[64,96,3,3]{3,2,1,0} %bitcast.28214, f32[64]{0} %bitcast.30431), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="U-Net_1/conv2d_100_1/convolution" source_file="/home/jubranakram/virtual-envs/tf-ml/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-05-29 14:04:05.086252: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.37 = (f32[7,32,128,128]{3,2,1,0}, u8[0]{0}) custom-call(f32[7,64,128,128]{3,2,1,0} %bitcast.30617, f32[32,64,3,3]{3,2,1,0} %bitcast.28256, f32[32]{0} %bitcast.30677), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="U-Net_1/conv2d_102_1/convolution" source_file="/home/jubranakram/virtual-envs/tf-ml/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-05-29 14:04:05.309186: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.38 = (f32[7,16,256,256]{3,2,1,0}, u8[0]{0}) custom-call(f32[7,48,256,256]{3,2,1,0} %bitcast.30868, f32[16,48,3,3]{3,2,1,0} %bitcast.28298, f32[16]{0} %bitcast.30928), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="U-Net_1/conv2d_104_1/convolution" source_file="/home/jubranakram/virtual-envs/tf-ml/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 652ms/step - accuracy: 0.1391 - loss: 0.4988 - multiclass_jaccard_index: 0.0848
# 2025-05-29 14:04:12.980740: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.34 = (f32[14,128,16,16]{3,2,1,0}, u8[0]{0}) custom-call(f32[14,32,16,16]{3,2,1,0} %bitcast.1189, f32[128,32,3,3]{3,2,1,0} %bitcast.1196, f32[128]{0} %bitcast.1198), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="U-Net_1/conv2d_96_1/convolution" source_file="/home/jubranakram/virtual-envs/tf-ml/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-05-29 14:04:13.055098: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.35 = (f32[14,96,32,32]{3,2,1,0}, u8[0]{0}) custom-call(f32[14,128,32,32]{3,2,1,0} %bitcast.1219, f32[96,128,3,3]{3,2,1,0} %bitcast.1226, f32[96]{0} %bitcast.1228), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="U-Net_1/conv2d_98_1/convolution" source_file="/home/jubranakram/virtual-envs/tf-ml/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-05-29 14:04:13.187937: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.36 = (f32[14,64,64,64]{3,2,1,0}, u8[0]{0}) custom-call(f32[14,96,64,64]{3,2,1,0} %bitcast.1249, f32[64,96,3,3]{3,2,1,0} %bitcast.1256, f32[64]{0} %bitcast.1258), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="U-Net_1/conv2d_100_1/convolution" source_file="/home/jubranakram/virtual-envs/tf-ml/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-05-29 14:04:13.408353: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.37 = (f32[14,32,128,128]{3,2,1,0}, u8[0]{0}) custom-call(f32[14,64,128,128]{3,2,1,0} %bitcast.1279, f32[32,64,3,3]{3,2,1,0} %bitcast.1286, f32[32]{0} %bitcast.1288), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="U-Net_1/conv2d_102_1/convolution" source_file="/home/jubranakram/virtual-envs/tf-ml/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 2025-05-29 14:04:13.760172: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.38 = (f32[14,16,256,256]{3,2,1,0}, u8[0]{0}) custom-call(f32[14,48,256,256]{3,2,1,0} %bitcast.1309, f32[16,48,3,3]{3,2,1,0} %bitcast.1316, f32[16]{0} %bitcast.1318), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="U-Net_1/conv2d_104_1/convolution" source_file="/home/jubranakram/virtual-envs/tf-ml/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 25s 803ms/step - accuracy: 0.1452 - loss: 0.4978 - multiclass_jaccard_index: 0.0871 - val_accuracy: 0.3823 - val_loss: 0.4569 - val_multiclass_jaccard_index: 0.1733
# Epoch 2/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.4783 - loss: 0.4530 - multiclass_jaccard_index: 0.2311 - val_accuracy: 0.3845 - val_loss: 0.4508 - val_multiclass_jaccard_index: 0.2075
# Epoch 3/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.4768 - loss: 0.4489 - multiclass_jaccard_index: 0.2584 - val_accuracy: 0.3924 - val_loss: 0.4454 - val_multiclass_jaccard_index: 0.2175
# Epoch 4/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.5255 - loss: 0.4444 - multiclass_jaccard_index: 0.2741 - val_accuracy: 0.4527 - val_loss: 0.4406 - val_multiclass_jaccard_index: 0.2395
# Epoch 5/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.5666 - loss: 0.4418 - multiclass_jaccard_index: 0.2884 - val_accuracy: 0.5764 - val_loss: 0.4342 - val_multiclass_jaccard_index: 0.2957
# Epoch 6/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.6348 - loss: 0.4287 - multiclass_jaccard_index: 0.3685 - val_accuracy: 0.5568 - val_loss: 0.4270 - val_multiclass_jaccard_index: 0.3318
# Epoch 7/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.6763 - loss: 0.4133 - multiclass_jaccard_index: 0.4414 - val_accuracy: 0.6302 - val_loss: 0.4094 - val_multiclass_jaccard_index: 0.3757
# Epoch 8/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.6991 - loss: 0.4044 - multiclass_jaccard_index: 0.4799 - val_accuracy: 0.6576 - val_loss: 0.3972 - val_multiclass_jaccard_index: 0.4157
# Epoch 9/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.7012 - loss: 0.4018 - multiclass_jaccard_index: 0.4824 - val_accuracy: 0.6620 - val_loss: 0.3949 - val_multiclass_jaccard_index: 0.4272
# Epoch 10/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.7110 - loss: 0.3958 - multiclass_jaccard_index: 0.4990 - val_accuracy: 0.6703 - val_loss: 0.3911 - val_multiclass_jaccard_index: 0.4361
# Epoch 11/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.7017 - loss: 0.3961 - multiclass_jaccard_index: 0.4772 - val_accuracy: 0.6771 - val_loss: 0.3862 - val_multiclass_jaccard_index: 0.4520
# Epoch 12/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - accuracy: 0.7466 - loss: 0.3909 - multiclass_jaccard_index: 0.5389 - val_accuracy: 0.6475 - val_loss: 0.3953 - val_multiclass_jaccard_index: 0.4200
# Epoch 13/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.7364 - loss: 0.3942 - multiclass_jaccard_index: 0.5274 - val_accuracy: 0.6590 - val_loss: 0.3832 - val_multiclass_jaccard_index: 0.4341
# Epoch 14/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.7253 - loss: 0.3858 - multiclass_jaccard_index: 0.5092 - val_accuracy: 0.6835 - val_loss: 0.3793 - val_multiclass_jaccard_index: 0.4574
# Epoch 15/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.7439 - loss: 0.3829 - multiclass_jaccard_index: 0.5330 - val_accuracy: 0.6909 - val_loss: 0.3733 - val_multiclass_jaccard_index: 0.4822
# Epoch 16/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.7539 - loss: 0.3806 - multiclass_jaccard_index: 0.5546 - val_accuracy: 0.7040 - val_loss: 0.3695 - val_multiclass_jaccard_index: 0.4952
# Epoch 17/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.7630 - loss: 0.3814 - multiclass_jaccard_index: 0.5601 - val_accuracy: 0.6987 - val_loss: 0.3686 - val_multiclass_jaccard_index: 0.4792
# Epoch 18/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.7601 - loss: 0.3749 - multiclass_jaccard_index: 0.5666 - val_accuracy: 0.6785 - val_loss: 0.3716 - val_multiclass_jaccard_index: 0.4690
# Epoch 19/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.7694 - loss: 0.3732 - multiclass_jaccard_index: 0.5813 - val_accuracy: 0.7023 - val_loss: 0.3636 - val_multiclass_jaccard_index: 0.4996
# Epoch 20/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.7841 - loss: 0.3682 - multiclass_jaccard_index: 0.6004 - val_accuracy: 0.7204 - val_loss: 0.3574 - val_multiclass_jaccard_index: 0.5190
# Epoch 21/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.7835 - loss: 0.3654 - multiclass_jaccard_index: 0.6039 - val_accuracy: 0.7336 - val_loss: 0.3566 - val_multiclass_jaccard_index: 0.5454
# Epoch 22/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.7735 - loss: 0.3729 - multiclass_jaccard_index: 0.5911 - val_accuracy: 0.7222 - val_loss: 0.3551 - val_multiclass_jaccard_index: 0.5159
# Epoch 23/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.7939 - loss: 0.3652 - multiclass_jaccard_index: 0.6212 - val_accuracy: 0.6589 - val_loss: 0.3755 - val_multiclass_jaccard_index: 0.4593
# Epoch 24/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.7901 - loss: 0.3663 - multiclass_jaccard_index: 0.6152 - val_accuracy: 0.7259 - val_loss: 0.3549 - val_multiclass_jaccard_index: 0.5261
# Epoch 25/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.8106 - loss: 0.3598 - multiclass_jaccard_index: 0.6462 - val_accuracy: 0.6710 - val_loss: 0.3727 - val_multiclass_jaccard_index: 0.4710
# Epoch 26/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - accuracy: 0.7828 - loss: 0.3606 - multiclass_jaccard_index: 0.6104 - val_accuracy: 0.7300 - val_loss: 0.3533 - val_multiclass_jaccard_index: 0.5367
# Epoch 27/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.8046 - loss: 0.3555 - multiclass_jaccard_index: 0.6422 - val_accuracy: 0.7142 - val_loss: 0.3550 - val_multiclass_jaccard_index: 0.5207
# Epoch 28/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - accuracy: 0.7967 - loss: 0.3582 - multiclass_jaccard_index: 0.6290 - val_accuracy: 0.7192 - val_loss: 0.3524 - val_multiclass_jaccard_index: 0.5263
# Epoch 29/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.8104 - loss: 0.3499 - multiclass_jaccard_index: 0.6502 - val_accuracy: 0.7109 - val_loss: 0.3545 - val_multiclass_jaccard_index: 0.5175
# Epoch 30/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.8108 - loss: 0.3541 - multiclass_jaccard_index: 0.6496 - val_accuracy: 0.7069 - val_loss: 0.3550 - val_multiclass_jaccard_index: 0.5169
# Epoch 31/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.8169 - loss: 0.3534 - multiclass_jaccard_index: 0.6631 - val_accuracy: 0.6894 - val_loss: 0.3620 - val_multiclass_jaccard_index: 0.5025
# Epoch 32/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.8085 - loss: 0.3490 - multiclass_jaccard_index: 0.6527 - val_accuracy: 0.7014 - val_loss: 0.3562 - val_multiclass_jaccard_index: 0.5119
# Epoch 33/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.8134 - loss: 0.3512 - multiclass_jaccard_index: 0.6617 - val_accuracy: 0.7264 - val_loss: 0.3492 - val_multiclass_jaccard_index: 0.5409
# Epoch 34/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.8213 - loss: 0.3483 - multiclass_jaccard_index: 0.6700 - val_accuracy: 0.6978 - val_loss: 0.3557 - val_multiclass_jaccard_index: 0.5117
# Epoch 35/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.8260 - loss: 0.3473 - multiclass_jaccard_index: 0.6756 - val_accuracy: 0.6919 - val_loss: 0.3592 - val_multiclass_jaccard_index: 0.5069
# Epoch 36/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.8386 - loss: 0.3492 - multiclass_jaccard_index: 0.6975 - val_accuracy: 0.7293 - val_loss: 0.3478 - val_multiclass_jaccard_index: 0.5459
# Epoch 37/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.8326 - loss: 0.3439 - multiclass_jaccard_index: 0.6850 - val_accuracy: 0.7254 - val_loss: 0.3480 - val_multiclass_jaccard_index: 0.5419
# Epoch 38/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.8272 - loss: 0.3475 - multiclass_jaccard_index: 0.6772 - val_accuracy: 0.7426 - val_loss: 0.3459 - val_multiclass_jaccard_index: 0.5659
# Epoch 39/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.8304 - loss: 0.3420 - multiclass_jaccard_index: 0.6845 - val_accuracy: 0.7283 - val_loss: 0.3463 - val_multiclass_jaccard_index: 0.5470
# Epoch 40/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 0.8335 - loss: 0.3423 - multiclass_jaccard_index: 0.6917 - val_accuracy: 0.6891 - val_loss: 0.3604 - val_multiclass_jaccard_index: 0.5067
# Epoch 41/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 0.8254 - loss: 0.3427 - multiclass_jaccard_index: 0.6790 - val_accuracy: 0.6908 - val_loss: 0.3590 - val_multiclass_jaccard_index: 0.5081
# Epoch 42/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - accuracy: 0.8371 - loss: 0.3378 - multiclass_jaccard_index: 0.6937 - val_accuracy: 0.6851 - val_loss: 0.3605 - val_multiclass_jaccard_index: 0.5029
# Epoch 43/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - accuracy: 0.8193 - loss: 0.3446 - multiclass_jaccard_index: 0.6680 - val_accuracy: 0.7231 - val_loss: 0.3497 - val_multiclass_jaccard_index: 0.5443
# Epoch 44/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 0.8509 - loss: 0.3455 - multiclass_jaccard_index: 0.7176 - val_accuracy: 0.7461 - val_loss: 0.3415 - val_multiclass_jaccard_index: 0.5721
# Epoch 45/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 0.8445 - loss: 0.3368 - multiclass_jaccard_index: 0.7079 - val_accuracy: 0.7390 - val_loss: 0.3413 - val_multiclass_jaccard_index: 0.5611
# Epoch 46/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.8470 - loss: 0.3344 - multiclass_jaccard_index: 0.7093 - val_accuracy: 0.6973 - val_loss: 0.3540 - val_multiclass_jaccard_index: 0.5167
# Epoch 47/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 0.8387 - loss: 0.3377 - multiclass_jaccard_index: 0.6983 - val_accuracy: 0.7264 - val_loss: 0.3466 - val_multiclass_jaccard_index: 0.5468
# Epoch 48/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 0.8401 - loss: 0.3442 - multiclass_jaccard_index: 0.6975 - val_accuracy: 0.6704 - val_loss: 0.3665 - val_multiclass_jaccard_index: 0.4895
# Epoch 49/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 0.8349 - loss: 0.3361 - multiclass_jaccard_index: 0.6957 - val_accuracy: 0.6731 - val_loss: 0.3603 - val_multiclass_jaccard_index: 0.4920
# Epoch 50/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 0.8392 - loss: 0.3389 - multiclass_jaccard_index: 0.6979 - val_accuracy: 0.7148 - val_loss: 0.3515 - val_multiclass_jaccard_index: 0.5388
# Epoch 51/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 0.8434 - loss: 0.3318 - multiclass_jaccard_index: 0.7074 - val_accuracy: 0.7377 - val_loss: 0.3422 - val_multiclass_jaccard_index: 0.5600
# Epoch 52/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - accuracy: 0.8248 - loss: 0.3358 - multiclass_jaccard_index: 0.6773 - val_accuracy: 0.7397 - val_loss: 0.3423 - val_multiclass_jaccard_index: 0.5655
# Epoch 53/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - accuracy: 0.8441 - loss: 0.3333 - multiclass_jaccard_index: 0.7079 - val_accuracy: 0.7115 - val_loss: 0.3512 - val_multiclass_jaccard_index: 0.5333
# Epoch 54/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.8488 - loss: 0.3327 - multiclass_jaccard_index: 0.7146 - val_accuracy: 0.7138 - val_loss: 0.3545 - val_multiclass_jaccard_index: 0.5363
# Epoch 55/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.8397 - loss: 0.3301 - multiclass_jaccard_index: 0.6991 - val_accuracy: 0.7119 - val_loss: 0.3522 - val_multiclass_jaccard_index: 0.5331
# Epoch 56/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.8433 - loss: 0.3347 - multiclass_jaccard_index: 0.7050 - val_accuracy: 0.6691 - val_loss: 0.3677 - val_multiclass_jaccard_index: 0.4908
# Epoch 57/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.8388 - loss: 0.3361 - multiclass_jaccard_index: 0.7017 - val_accuracy: 0.6676 - val_loss: 0.3642 - val_multiclass_jaccard_index: 0.4876
# Epoch 58/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.8334 - loss: 0.3304 - multiclass_jaccard_index: 0.6932 - val_accuracy: 0.7522 - val_loss: 0.3384 - val_multiclass_jaccard_index: 0.5806
# Epoch 59/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.8611 - loss: 0.3278 - multiclass_jaccard_index: 0.7334 - val_accuracy: 0.7244 - val_loss: 0.3483 - val_multiclass_jaccard_index: 0.5500
# Epoch 60/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.8601 - loss: 0.3365 - multiclass_jaccard_index: 0.7328 - val_accuracy: 0.7151 - val_loss: 0.3508 - val_multiclass_jaccard_index: 0.5397
# Epoch 61/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.8649 - loss: 0.3288 - multiclass_jaccard_index: 0.7404 - val_accuracy: 0.7379 - val_loss: 0.3435 - val_multiclass_jaccard_index: 0.5647
# Epoch 62/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.8402 - loss: 0.3219 - multiclass_jaccard_index: 0.7037 - val_accuracy: 0.7295 - val_loss: 0.3467 - val_multiclass_jaccard_index: 0.5556
# Epoch 63/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.8538 - loss: 0.3270 - multiclass_jaccard_index: 0.7202 - val_accuracy: 0.6905 - val_loss: 0.3572 - val_multiclass_jaccard_index: 0.5131
# Epoch 64/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.8494 - loss: 0.3249 - multiclass_jaccard_index: 0.7141 - val_accuracy: 0.7349 - val_loss: 0.3443 - val_multiclass_jaccard_index: 0.5637
# Epoch 65/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.8530 - loss: 0.3286 - multiclass_jaccard_index: 0.7219 - val_accuracy: 0.7091 - val_loss: 0.3511 - val_multiclass_jaccard_index: 0.5336
# Epoch 66/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - accuracy: 0.8536 - loss: 0.3219 - multiclass_jaccard_index: 0.7235 - val_accuracy: 0.7339 - val_loss: 0.3463 - val_multiclass_jaccard_index: 0.5624
# Epoch 67/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.8594 - loss: 0.3313 - multiclass_jaccard_index: 0.7337 - val_accuracy: 0.7101 - val_loss: 0.3528 - val_multiclass_jaccard_index: 0.5359
# Epoch 68/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.8679 - loss: 0.3204 - multiclass_jaccard_index: 0.7460 - val_accuracy: 0.7290 - val_loss: 0.3466 - val_multiclass_jaccard_index: 0.5564
# Epoch 69/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.8737 - loss: 0.3187 - multiclass_jaccard_index: 0.7519 - val_accuracy: 0.7063 - val_loss: 0.3564 - val_multiclass_jaccard_index: 0.5315
# Epoch 70/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.8709 - loss: 0.3294 - multiclass_jaccard_index: 0.7510 - val_accuracy: 0.7290 - val_loss: 0.3508 - val_multiclass_jaccard_index: 0.5580
# Epoch 71/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.8665 - loss: 0.3250 - multiclass_jaccard_index: 0.7415 - val_accuracy: 0.7280 - val_loss: 0.3488 - val_multiclass_jaccard_index: 0.5553
# Epoch 72/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.8755 - loss: 0.3196 - multiclass_jaccard_index: 0.7545 - val_accuracy: 0.7367 - val_loss: 0.3469 - val_multiclass_jaccard_index: 0.5654
# Epoch 73/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.8633 - loss: 0.3194 - multiclass_jaccard_index: 0.7366 - val_accuracy: 0.7362 - val_loss: 0.3464 - val_multiclass_jaccard_index: 0.5657
# Epoch 74/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.8574 - loss: 0.3240 - multiclass_jaccard_index: 0.7249 - val_accuracy: 0.7460 - val_loss: 0.3438 - val_multiclass_jaccard_index: 0.5759
# Epoch 75/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.8669 - loss: 0.3143 - multiclass_jaccard_index: 0.7402 - val_accuracy: 0.7331 - val_loss: 0.3488 - val_multiclass_jaccard_index: 0.5624
# Epoch 76/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.8737 - loss: 0.3169 - multiclass_jaccard_index: 0.7538 - val_accuracy: 0.7418 - val_loss: 0.3454 - val_multiclass_jaccard_index: 0.5723
# Epoch 77/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.8848 - loss: 0.3209 - multiclass_jaccard_index: 0.7734 - val_accuracy: 0.7354 - val_loss: 0.3460 - val_multiclass_jaccard_index: 0.5630
# Epoch 78/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.8692 - loss: 0.3194 - multiclass_jaccard_index: 0.7434 - val_accuracy: 0.7342 - val_loss: 0.3509 - val_multiclass_jaccard_index: 0.5643
# Epoch 79/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - accuracy: 0.8759 - loss: 0.3203 - multiclass_jaccard_index: 0.7582 - val_accuracy: 0.7035 - val_loss: 0.3602 - val_multiclass_jaccard_index: 0.5272
# Epoch 80/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 0.8533 - loss: 0.3202 - multiclass_jaccard_index: 0.7207 - val_accuracy: 0.7125 - val_loss: 0.3568 - val_multiclass_jaccard_index: 0.5366
# Epoch 81/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - accuracy: 0.8709 - loss: 0.3269 - multiclass_jaccard_index: 0.7488 - val_accuracy: 0.7531 - val_loss: 0.3416 - val_multiclass_jaccard_index: 0.5824
# Epoch 82/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 0.8515 - loss: 0.3191 - multiclass_jaccard_index: 0.7177 - val_accuracy: 0.7412 - val_loss: 0.3431 - val_multiclass_jaccard_index: 0.5682
# Epoch 83/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - accuracy: 0.8800 - loss: 0.3198 - multiclass_jaccard_index: 0.7613 - val_accuracy: 0.7192 - val_loss: 0.3539 - val_multiclass_jaccard_index: 0.5460
# Epoch 84/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 0.8705 - loss: 0.3228 - multiclass_jaccard_index: 0.7509 - val_accuracy: 0.7160 - val_loss: 0.3562 - val_multiclass_jaccard_index: 0.5408
# Epoch 85/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 0.8647 - loss: 0.3157 - multiclass_jaccard_index: 0.7360 - val_accuracy: 0.7031 - val_loss: 0.3615 - val_multiclass_jaccard_index: 0.5271
# Epoch 86/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 0.8819 - loss: 0.3067 - multiclass_jaccard_index: 0.7671 - val_accuracy: 0.7259 - val_loss: 0.3496 - val_multiclass_jaccard_index: 0.5525
# Epoch 87/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 0.8757 - loss: 0.3139 - multiclass_jaccard_index: 0.7553 - val_accuracy: 0.7470 - val_loss: 0.3449 - val_multiclass_jaccard_index: 0.5793
# Epoch 88/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - accuracy: 0.8769 - loss: 0.3102 - multiclass_jaccard_index: 0.7596 - val_accuracy: 0.7214 - val_loss: 0.3516 - val_multiclass_jaccard_index: 0.5453
# Epoch 89/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - accuracy: 0.8602 - loss: 0.3086 - multiclass_jaccard_index: 0.7308 - val_accuracy: 0.7470 - val_loss: 0.3479 - val_multiclass_jaccard_index: 0.5790
# Epoch 90/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.8802 - loss: 0.3094 - multiclass_jaccard_index: 0.7660 - val_accuracy: 0.7287 - val_loss: 0.3519 - val_multiclass_jaccard_index: 0.5530
# Epoch 91/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 0.8719 - loss: 0.3127 - multiclass_jaccard_index: 0.7468 - val_accuracy: 0.7331 - val_loss: 0.3481 - val_multiclass_jaccard_index: 0.5574
# Epoch 92/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - accuracy: 0.8794 - loss: 0.3126 - multiclass_jaccard_index: 0.7638 - val_accuracy: 0.7405 - val_loss: 0.3477 - val_multiclass_jaccard_index: 0.5692
# Epoch 93/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - accuracy: 0.8809 - loss: 0.3083 - multiclass_jaccard_index: 0.7645 - val_accuracy: 0.7309 - val_loss: 0.3549 - val_multiclass_jaccard_index: 0.5597
# Epoch 94/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 0.8788 - loss: 0.3075 - multiclass_jaccard_index: 0.7626 - val_accuracy: 0.7325 - val_loss: 0.3506 - val_multiclass_jaccard_index: 0.5582
# Epoch 95/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - accuracy: 0.8752 - loss: 0.3057 - multiclass_jaccard_index: 0.7536 - val_accuracy: 0.7222 - val_loss: 0.3531 - val_multiclass_jaccard_index: 0.5481
# Epoch 96/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.8810 - loss: 0.3125 - multiclass_jaccard_index: 0.7650 - val_accuracy: 0.7287 - val_loss: 0.3497 - val_multiclass_jaccard_index: 0.5536
# Epoch 97/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - accuracy: 0.8839 - loss: 0.3101 - multiclass_jaccard_index: 0.7705 - val_accuracy: 0.7092 - val_loss: 0.3583 - val_multiclass_jaccard_index: 0.5326
# Epoch 98/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 0.8737 - loss: 0.3136 - multiclass_jaccard_index: 0.7526 - val_accuracy: 0.7237 - val_loss: 0.3547 - val_multiclass_jaccard_index: 0.5507
# Epoch 99/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - accuracy: 0.8756 - loss: 0.3071 - multiclass_jaccard_index: 0.7585 - val_accuracy: 0.7393 - val_loss: 0.3486 - val_multiclass_jaccard_index: 0.5674
# Epoch 100/100
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - accuracy: 0.8890 - loss: 0.3062 - multiclass_jaccard_index: 0.7782 - val_accuracy: 0.7353 - val_loss: 0.3503 - val_multiclass_jaccard_index: 0.5650

# %%
history_rec = model_history

# %%
train_loss = history_rec.history['loss']
val_loss = history_rec.history['val_loss']
num_epochs = range(NUM_EPOCHS)

plt.plot(num_epochs, train_loss, label='Train')
plt.plot(num_epochs, val_loss, label='Validation')
plt.title('Loss')
plt.grid()
plt.legend()

# %%
test_image_number = np.random.randint(X_test.shape[0])

test_image = X_test[test_image_number]
y_test_argmax = np.argmax(y_test, axis=3)
ground_truth_image = y_test_argmax[test_image_number]

test_image_input = np.expand_dims(test_image, 0)

prediction = model.predict(test_image_input)
predicted_image = np.argmax(prediction, axis=3)
predicted_image = predicted_image[0, :, :]
# Out:
# 2025-05-29 14:06:29.181242: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:549] Omitted potentially buggy algorithm eng14{k25=0} for conv %cudnn-conv-bias-activation.35 = (f32[1,96,32,32]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,128,32,32]{3,2,1,0} %bitcast.603, f32[96,128,3,3]{3,2,1,0} %bitcast.610, f32[96]{0} %bitcast.612), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", metadata={op_type="Conv2D" op_name="U-Net_1/conv2d_98_1/convolution" source_file="/home/jubranakram/virtual-envs/tf-ml/lib/python3.10/site-packages/tensorflow/python/framework/ops.py" source_line=1200}, backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step

# %%
fig, axs = plt.subplots(1,3, figsize=(10,6))
axs = axs.flatten()

axs[0].imshow(test_image)
axs[1].imshow(ground_truth_image)
axs[2].imshow(predicted_image)

# %% [markdown]
# __Save Model__

# %%
model.save('../model/semantic-segmentation-aerial-unet-v0.keras')

# %%
# !ls -lah ../model
# Out:
# total 25M
# drwxr-xr-x 2 jubranakram jubranakram 4.0K May 29 10:12 .
# drwxr-xr-x 7 jubranakram jubranakram 4.0K May 28 20:33 ..
# -rw-r--r-- 1 jubranakram jubranakram  21M May 29 09:59 semantic-segmentation-aerial-unet-v0.h5
# -rw-r--r-- 1 jubranakram jubranakram 4.1M May 29 14:06 semantic-segmentation-aerial-unet-v0.keras

# %%
from tensorflow.keras.models import load_model

# %%
saved_model = load_model('../model/semantic-segmentation-aerial-unet-v0.keras')

# %%
test_image_number = np.random.randint(X_test.shape[0])

test_image = X_test[test_image_number]
y_test_argmax = np.argmax(y_test, axis=3)
ground_truth_image = y_test_argmax[test_image_number]

test_image_input = np.expand_dims(test_image, 0)

prediction = saved_model.predict(test_image_input)
predicted_image = np.argmax(prediction, axis=3)
predicted_image = predicted_image[0, :, :]

fig, axs = plt.subplots(1,3, figsize=(10,6))
axs = axs.flatten()

axs[0].imshow(test_image)
axs[1].imshow(ground_truth_image)
axs[2].imshow(predicted_image)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
